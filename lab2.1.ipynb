# %% [markdown]
# ## Exercise: Analyzing and Visualizing Data with Matplotlib, Pandas, and NumPy
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per $10,000
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - % lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's
#
# ### Part 1: Data Preparation
#
# In this part of the exercise, you will use Pandas and NumPy to load and preprocess data. For this exercise, we will use a dataset of housing prices in Boston.
#
# 1.  Download the Boston Housing dataset from [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data) and save it to your local computer.
# 2.  Load the dataset into a Pandas DataFrame and examine its contents. The dataset should have 506 rows and 14 columns.
# 3.  Use NumPy to calculate some basic statistics about the dataset, such as the mean, median, standard deviation, minimum, and maximum values of each column.
# 4.  Clean the dataset by removing any missing or invalid values. You can use Pandas' `dropna()` method for this.

# %%
# !pip install pandas yfinance matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\python312\lib\site-packages (2.1.2)
# Collecting yfinance
#   Using cached yfinance-0.2.37-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib in c:\python312\lib\site-packages (3.8.0)
# Requirement already satisfied: seaborn in c:\python312\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\python312\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\python312\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: requests>=2.31 in c:\python312\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Using cached lxml-5.1.0-cp312-cp312-win_amd64.whl.metadata (3.6 kB)
# Collecting appdirs>=1.4.4 (from yfinance)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.0-py3-none-any.whl
# Requirement already satisfied: peewee>=3.16.2 in c:\python312\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\python312\lib\site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python312\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\python312\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\python312\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\python312\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python312\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests>=2.31->yfinance) (2023.11.17)
# Using cached yfinance-0.2.37-py2.py3-none-any.whl (72 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Using cached lxml-5.1.0-cp312-cp312-win_amd64.whl (3.9 MB)
# Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Installing collected packages: multitasking, appdirs, lxml, html5lib, frozendict, yfinance
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python312\\Scripts\\sample.exe' -> 'C:\\Python312\\Scripts\\sample.exe.deleteme'
#
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

names = ['CRIM', 'ZN' , 'INDUS' , 'CHAS' , 'NOX', 'RM' , 'AGE', 'DIS', 'RAD' , 'TAX' , 'PTRATIO' , 'B' , 'LSTAT' , 'MEDV']
df = pd.read_csv('housing.data',delim_whitespace=True,header = None , names = names)

print(df.head())
print(df.shape)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# (506, 14)

# %%
import numpy as np
mean = np.mean(df,axis = 0)
median = np.median(df,axis = 0)
std = np.std(df, axis =0)
minimum = np.min(df , axis = 0)
maximum = np.max(df , axis = 0)

print("Mean: ", mean)
# Out:
# Mean:  CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# MEDV        22.532806
# dtype: float64

# %% [markdown]
# ### Part 2: Data Visualization
#
# In this part of the exercise, you will use Matplotlib to create some visualizations of the housing data.
#
# 1.  Create a scatter plot of the housing prices (`MEDV`) versus the number of rooms (`RM`). Label the axes and add a title to the plot.
# 2.  Create a histogram of the housing prices (`MEDV`). Label the axes and add a title to the plot.
# 3.  Create a box plot of the housing prices (`MEDV`) grouped by the proximity to employment centers (`DIS`). Label the axes and add a title to the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data into a DataFrame
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = pd.read_csv('housing.data', header=None, delim_whitespace=True, names=names)

# Extract relevant columns
rooms = data['RM']
prices = data['MEDV']

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(rooms, prices, alpha=0.6, color='b')

# Add labels and title
plt.xlabel('Number of Rooms (RM)')
plt.ylabel('Housing Prices (MEDV)')
plt.title('Housing Prices vs Number of Rooms')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data into a DataFrame
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = pd.read_csv('housing.data', header=None, delim_whitespace=True, names=names)

# Extract housing prices
prices = data['MEDV']

# Create histogram
plt.figure(figsize=(10, 6))
plt.hist(prices, bins=30, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Housing Prices (MEDV)')
plt.ylabel('Frequency')
plt.title('Histogram of Housing Prices')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data into a DataFrame
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = pd.read_csv('housing.data', header=None, delim_whitespace=True, names=names)

# Group housing prices by proximity to employment centers
dis_groups = data.groupby(pd.cut(data['DIS'], bins=5))

# Extract prices for each group
group_labels = []
group_data = []

for name, group in dis_groups:
    group_labels.append(name)
    group_data.append(group['MEDV'])

# Create box plot
plt.figure(figsize=(10, 6))
plt.boxplot(group_data, labels=group_labels)

# Add labels and title
plt.xlabel('Proximity to Employment Centers (DIS)')
plt.ylabel('Housing Prices (MEDV)')
plt.title('Box Plot of Housing Prices Grouped by Proximity to Employment Centers')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_7972\4169019940.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dis_groups = data.groupby(pd.cut(data['DIS'], bins=5))

# %% [markdown]
# ### Part 3: Data Analysis
#
# In this part of the exercise, you will use Pandas and NumPy to perform some basic data analysis on the housing data.
#
# 1.  Calculate the correlation coefficient between the housing prices (`MEDV`) and the number of rooms (`RM`) using NumPy's `corrcoef()` method.
# 2.  Calculate the mean housing price (`MEDV`) for each neighborhood (`CHAS`). You can use Pandas' `groupby()` method for this.
# 3.  Calculate the percentage of houses that have more than 7 rooms (`RM`). You can use Pandas' `value_counts()` method for this.

# %%
import numpy as np

# Assuming 'data' is your DataFrame containing the housing data
correlation_coefficient = np.corrcoef(data['RM'], data['MEDV'])[0, 1]
print("Correlation coefficient between RM and MEDV:", correlation_coefficient)


# Group by 'CHAS' and calculate mean 'MEDV' for each group
mean_prices_by_neighborhood = data.groupby('CHAS')['MEDV'].mean()
print("Mean housing price by neighborhood:\n", mean_prices_by_neighborhood)

# Count the number of houses with more than 7 rooms
num_houses_more_than_7_rooms = (data['RM'] > 7).sum()

# Total number of houses
total_houses = len(data)

# Calculate percentage
percentage_more_than_7_rooms = (num_houses_more_than_7_rooms / total_houses) * 100
print("Percentage of houses with more than 7 rooms:", percentage_more_than_7_rooms)
# Out:
# Correlation coefficient between RM and MEDV: 0.6953599470715395
# Mean housing price by neighborhood:
#  CHAS
# 0    22.093843
# 1    28.440000
# Name: MEDV, dtype: float64
# Percentage of houses with more than 7 rooms: 12.648221343873518

# %% [markdown]
# ### Part 4: Putting it all together
#
# In this final part of the exercise, you will use all three libraries to create a complete data analysis and visualization pipeline.
#
# 1.  Load the dataset and preprocess it as before.
# 2.  Create the scatter plot and histogram as before.
# 3.  Calculate the correlation coefficient between the housing prices and the number of rooms as before.
# 4.  Group the data by the proximity to employment centers and calculate the mean housing prices as before.
# 5.  Create a bar chart of the mean housing prices by proximity to employment centers. Label the axes and add a title to the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = pd.read_csv('housing.data', header=None, delim_whitespace=True, names=names)


# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(data['RM'], data['MEDV'], alpha=0.6, color='b')
plt.xlabel('Number of Rooms (RM)')
plt.ylabel('Housing Prices (MEDV)')
plt.title('Housing Prices vs Number of Rooms')
plt.grid(True)
plt.tight_layout()
plt.show()

# Histogram
plt.figure(figsize=(10, 6))
plt.hist(data['MEDV'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Housing Prices (MEDV)')
plt.ylabel('Frequency')
plt.title('Histogram of Housing Prices')
plt.grid(True)
plt.tight_layout()
plt.show()







correlation_coefficient = np.corrcoef(data['RM'], data['MEDV'])[0, 1]
print("Correlation coefficient between RM and MEDV:", correlation_coefficient)

mean_prices_by_proximity = data.groupby(pd.cut(data['DIS'], bins=5))['MEDV'].mean()
print("Mean housing prices by proximity to employment centers:\n", mean_prices_by_proximity)






plt.figure(figsize=(10, 6))
mean_prices_by_proximity.plot(kind='bar', color='skyblue')
plt.xlabel('Proximity to Employment Centers (DIS)')
plt.ylabel('Mean Housing Prices (MEDV)')
plt.title('Mean Housing Prices by Proximity to Employment Centers')
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Correlation coefficient between RM and MEDV: 0.6953599470715395
# Mean housing prices by proximity to employment centers:
#  DIS
# (1.119, 3.329]     20.277395
# (3.329, 5.528]     24.847183
# (5.528, 7.728]     25.295833
# (7.728, 9.927]     24.923077
# (9.927, 12.126]    22.320000
# Name: MEDV, dtype: float64
# C:\Users\Legion\AppData\Local\Temp\ipykernel_7972\1329677706.py:38: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_prices_by_proximity = data.groupby(pd.cut(data['DIS'], bins=5))['MEDV'].mean()
